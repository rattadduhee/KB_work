# %% [markdown]
# # STEP 0. Import

# %%
import os
import zipfile
import urllib.request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 1. Load Dataset

# %%
# 코드를 실행하세요.
# 데이터 다운로드 및 압축 풀기
url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
urllib.request.urlretrieve(url, 'rps.zip')
local_zip = 'rps.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('data/')
zip_ref.close()

# %%
# 코드를 실행하세요.
# data/rps 경로의 파일 확인
os.listdir('data/rps/')
# Out:
# ['paper', 'rock', 'scissors']

# %%
# 코드를 실행하세요.
# scissors 폴더의 첫 번째 데이터 경로
sample_data_dir = f"data/rps/scissors/{os.listdir('data/rps/scissors')[0]}"
sample_data_dir
# Out:
# 'data/rps/scissors/scissors01-000.png'

# %%
# 코드를 실행하세요.
# sample_data를 로드하세요.
from tensorflow.keras.preprocessing.image import load_img, img_to_array
sample_data = load_img(sample_data_dir, target_size=(150, 150))
sample_data = img_to_array(sample_data) / 255

# sample_data의 shape와 첫 번째 픽셀을 출력하세요.
sample_data.shape, sample_data[0, 0, :]
# Out:
# ((150, 150, 3), array([0.99607843, 0.99607843, 0.99607843], dtype=float32))

# %%
# sample_data를 시각화하세요.
plt.imshow(sample_data)
plt.show()

# %%
# 코드를 실행하세요.
# 'scissors', 'rock', 'paper'의 각 이미지 3개씩 subplot 하세요.
from tensorflow.keras.preprocessing.image import load_img, img_to_array

plt.figure(figsize = (9,9))

for i, c in enumerate(['scissors', 'rock', 'paper']) :
    files = os.listdir(f'data/rps/{c}')[:3]
    for j, file in enumerate(files) :
        plt.subplot(3,3, 3*i + j + 1)

        # 이미지 로드
        image = load_img(f'data/rps/{c}/{file}', target_size=(150, 150))
        image = img_to_array(image) / 255
        
        # plot
        plt.imshow(image)
        plt.axis(False)
        plt.title(c)
plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 2. 전처리 (ImageDataGenerator)
# `ImageDataGenerator`를 정의합니다.
#
# 다음의 옵션 값들로 Image Aumentation(이미지 변형) 옵션을 적절히 조절해 주세요
#
# * `rescale`: 이미지의 픽셀 값을 조정
# * `rotation_range`: 이미지 회전
# * `width_shift_range`: 가로 방향으로 이동
# * `height_shift_range`: 세로 방향으로 이동
# * `shear_range`: 이미지 굴절
# * `zoom_range`: 이미지 확대
# * `horizontal_flip`: 횡 방향으로 이미지 반전
# * `fill_mode`: 이미지를 이동이나 굴절시켰을 때 빈 픽셀 값에 대하여 값을 채우는 방식
# * `validation_split`: validation set의 구성 비율

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# 나머지 옵션은 자유롭게 사용하고 validation_split은 0.2로 지정하세요.
training_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.1,
      horizontal_flip=True,
      fill_mode='nearest',
      validation_split=0.2
)

# %% [markdown]
# ImageDataGenerator를 잘 만들어 주었다면, `flow_from_directory`로 이미지를 어떻게 공급해 줄 것인가를 지정해 주어야합니다.
#
# * train / validation set 전용 generator를 별도로 정의합니다.
# * `batch_size`를 정의합니다 (128)
# * `target_size`를 정의합니다. (150 x 150). 이미지를 알아서 타겟 사이즈 만큼 잘라내어 공급합니다.
# * `class_mode`는 3개 이상의 클래스인 경우 'categorical' 이진 분류의 경우 `binary`를 지정합니다.
# * `subset`을 지정합니다. (training / validation)

# %%
# training_generator 생성 (subset='training')

training_generator = training_datagen.flow_from_directory(
        os.path.join('/content/data/', 'rps'), 
        target_size=(150, 150),
        batch_size=128,
        class_mode='sparse',
        subset='training'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 # training_generator 생성 (subset='training')
# ----> 3 training_generator = training_datagen.flow_from_directory(
#       4         os.path.join('/content/data/', 'rps'),
#       5         target_size=(150, 150),
#       6         batch_size=128,
#       7         class_mode='sparse',
#       8         subset='training'
#       9 )
#
# File ~\anaconda3\lib\site-packages\keras\preprocessing\image.py:1650, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1564 def flow_from_directory(
#    1565     self,
#    1566     directory,
#    (...)
#    1580     keep_aspect_ratio=False,
#    1581 ):
#    1582     """Takes the path to a directory & generates batches of augmented data.
#    1583
#    1584     Args:
#    (...)
#    1648             and `y` is a numpy array of corresponding labels.
#    1649     """
# -> 1650     return DirectoryIterator(
#    1651         directory,
#    1652         self,
#    1653         target_size=target_size,
#    1654         color_mode=color_mode,
#    1655         keep_aspect_ratio=keep_aspect_ratio,
#    1656         classes=classes,
#    1657         class_mode=class_mode,
#    1658         data_format=self.data_format,
#    1659         batch_size=batch_size,
#    1660         shuffle=shuffle,
#    1661         seed=seed,
#    1662         save_to_dir=save_to_dir,
#    1663         save_prefix=save_prefix,
#    1664         save_format=save_format,
#    1665         follow_links=follow_links,
#    1666         subset=subset,
#    1667         interpolation=interpolation,
#    1668         dtype=self.dtype,
#    1669     )
#
# File ~\anaconda3\lib\site-packages\keras\preprocessing\image.py:563, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561 if not classes:
#     562     classes = []
# --> 563     for subdir in sorted(os.listdir(directory)):
#     564         if os.path.isdir(os.path.join(directory, subdir)):
#     565             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '/content/data/rps'

# %%
# validation_generator 생성 (subset='validation')
validation_generator = train_datagen.flow_from_directory(
        os.path.join('/content/data/'),
        target_size=(150, 150),
        batch_size=128,
        class_mode='sparse',
        subset='validation'
)
# Out:
# Found 504 images belonging to 3 classes.

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 3. 모델 정의 (Sequential)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential([
    # Conv2D, MaxPooling2D 조합으로 층을 쌓습니다. 첫번째 입력층의 input_shape은 (150, 150, 3)으로 지정합니다.
    tf.keras.layers.Conv2D(64, 3, activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2), 
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2, 2), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(512, activation=tf.nn.relu ), 
    tf.keras.layers.Dense(3, activation=tf.nn.softmax)    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 34, 34, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 147968)            0
#
#  dropout (Dropout)           (None, 147968)            0
#
#  dense (Dense)               (None, 512)               75760128
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 76,021,827
# Trainable params: 76,021,827
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 4. 컴파일 (compile)

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer="Adam",
              metrics=['acc'])

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 5. ModelCheckpoint 생성

# %%
# 코드를 실행하세요.
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint_path = "tmp_checkpoint.ckpt"
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 6. 학습 (fit)

# %%
history =
# Out:
# Epoch 1/25
# 16/16 [==============================] - ETA: 0s - loss: 2.5159 - acc: 0.3318
# Epoch 1: val_loss improved from inf to 1.09663, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 58s 3s/step - loss: 2.5159 - acc: 0.3318 - val_loss: 1.0966 - val_acc: 0.3611
# Epoch 2/25
# 16/16 [==============================] - ETA: 0s - loss: 1.0922 - acc: 0.3785
# Epoch 2: val_loss did not improve from 1.09663
# 16/16 [==============================] - 27s 2s/step - loss: 1.0922 - acc: 0.3785 - val_loss: 1.0973 - val_acc: 0.3353
# Epoch 3/25
# 16/16 [==============================] - ETA: 0s - loss: 1.0297 - acc: 0.4717
# Epoch 3: val_loss improved from 1.09663 to 0.99568, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 29s 2s/step - loss: 1.0297 - acc: 0.4717 - val_loss: 0.9957 - val_acc: 0.3770
# Epoch 4/25
# 16/16 [==============================] - ETA: 0s - loss: 0.8280 - acc: 0.6121
# Epoch 4: val_loss improved from 0.99568 to 0.99434, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 30s 2s/step - loss: 0.8280 - acc: 0.6121 - val_loss: 0.9943 - val_acc: 0.4563
# Epoch 5/25
# 16/16 [==============================] - ETA: 0s - loss: 0.7009 - acc: 0.6726
# Epoch 5: val_loss improved from 0.99434 to 0.87184, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 30s 2s/step - loss: 0.7009 - acc: 0.6726 - val_loss: 0.8718 - val_acc: 0.5833
# Epoch 6/25
# 16/16 [==============================] - ETA: 0s - loss: 0.5619 - acc: 0.7639
# Epoch 6: val_loss improved from 0.87184 to 0.71622, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 29s 2s/step - loss: 0.5619 - acc: 0.7639 - val_loss: 0.7162 - val_acc: 0.7361
# Epoch 7/25
# 16/16 [==============================] - ETA: 0s - loss: 0.4867 - acc: 0.8165
# Epoch 7: val_loss improved from 0.71622 to 0.66212, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 29s 2s/step - loss: 0.4867 - acc: 0.8165 - val_loss: 0.6621 - val_acc: 0.6925
# Epoch 8/25
# 16/16 [==============================] - ETA: 0s - loss: 0.3848 - acc: 0.8581
# Epoch 8: val_loss improved from 0.66212 to 0.54164, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 30s 2s/step - loss: 0.3848 - acc: 0.8581 - val_loss: 0.5416 - val_acc: 0.8294
# Epoch 9/25
# 16/16 [==============================] - ETA: 0s - loss: 0.3460 - acc: 0.8790
# Epoch 9: val_loss improved from 0.54164 to 0.51223, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 29s 2s/step - loss: 0.3460 - acc: 0.8790 - val_loss: 0.5122 - val_acc: 0.8234
# Epoch 10/25
# 16/16 [==============================] - ETA: 0s - loss: 0.3061 - acc: 0.8869
# Epoch 10: val_loss did not improve from 0.51223
# 16/16 [==============================] - 26s 2s/step - loss: 0.3061 - acc: 0.8869 - val_loss: 0.6881 - val_acc: 0.7341
# Epoch 11/25
# 16/16 [==============================] - ETA: 0s - loss: 0.2878 - acc: 0.9033
# Epoch 11: val_loss did not improve from 0.51223
# 16/16 [==============================] - 26s 2s/step - loss: 0.2878 - acc: 0.9033 - val_loss: 0.5558 - val_acc: 0.7937
# Epoch 12/25
# 16/16 [==============================] - ETA: 0s - loss: 0.2023 - acc: 0.9365
# Epoch 12: val_loss improved from 0.51223 to 0.50997, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 29s 2s/step - loss: 0.2023 - acc: 0.9365 - val_loss: 0.5100 - val_acc: 0.8095
# Epoch 13/25
# 16/16 [==============================] - ETA: 0s - loss: 0.1925 - acc: 0.9335
# Epoch 13: val_loss improved from 0.50997 to 0.40247, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 30s 2s/step - loss: 0.1925 - acc: 0.9335 - val_loss: 0.4025 - val_acc: 0.8452
# Epoch 14/25
# 16/16 [==============================] - ETA: 0s - loss: 0.1862 - acc: 0.9385
# Epoch 14: val_loss did not improve from 0.40247
# 16/16 [==============================] - 27s 2s/step - loss: 0.1862 - acc: 0.9385 - val_loss: 0.6991 - val_acc: 0.7440
# Epoch 15/25
# 16/16 [==============================] - ETA: 0s - loss: 0.2070 - acc: 0.9325
# Epoch 15: val_loss did not improve from 0.40247
# 16/16 [==============================] - 27s 2s/step - loss: 0.2070 - acc: 0.9325 - val_loss: 0.5312 - val_acc: 0.7758
# Epoch 16/25
# 16/16 [==============================] - ETA: 0s - loss: 0.1307 - acc: 0.9549
# Epoch 16: val_loss did not improve from 0.40247
# 16/16 [==============================] - 27s 2s/step - loss: 0.1307 - acc: 0.9549 - val_loss: 0.4705 - val_acc: 0.8254
# Epoch 17/25
# 16/16 [==============================] - ETA: 0s - loss: 0.1196 - acc: 0.9563
# Epoch 17: val_loss did not improve from 0.40247
# 16/16 [==============================] - 26s 2s/step - loss: 0.1196 - acc: 0.9563 - val_loss: 0.7574 - val_acc: 0.7540
# Epoch 18/25
# 16/16 [==============================] - ETA: 0s - loss: 0.1111 - acc: 0.9683
# Epoch 18: val_loss did not improve from 0.40247
# 16/16 [==============================] - 26s 2s/step - loss: 0.1111 - acc: 0.9683 - val_loss: 0.5187 - val_acc: 0.8452
# Epoch 19/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0890 - acc: 0.9722
# Epoch 19: val_loss did not improve from 0.40247
# 16/16 [==============================] - 26s 2s/step - loss: 0.0890 - acc: 0.9722 - val_loss: 0.4544 - val_acc: 0.8512
# Epoch 20/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0974 - acc: 0.9633
# Epoch 20: val_loss did not improve from 0.40247
# 16/16 [==============================] - 26s 2s/step - loss: 0.0974 - acc: 0.9633 - val_loss: 0.5358 - val_acc: 0.8294
# Epoch 21/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0829 - acc: 0.9722
# Epoch 21: val_loss improved from 0.40247 to 0.31833, saving model to tmp_checkpoint.ckpt
# 16/16 [==============================] - 34s 2s/step - loss: 0.0829 - acc: 0.9722 - val_loss: 0.3183 - val_acc: 0.8948
# Epoch 22/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0989 - acc: 0.9678
# Epoch 22: val_loss did not improve from 0.31833
# 16/16 [==============================] - 27s 2s/step - loss: 0.0989 - acc: 0.9678 - val_loss: 0.4507 - val_acc: 0.8353
# Epoch 23/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0905 - acc: 0.9742
# Epoch 23: val_loss did not improve from 0.31833
# 16/16 [==============================] - 26s 2s/step - loss: 0.0905 - acc: 0.9742 - val_loss: 0.4489 - val_acc: 0.8532
# Epoch 24/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0743 - acc: 0.9762
# Epoch 24: val_loss did not improve from 0.31833
# 16/16 [==============================] - 27s 2s/step - loss: 0.0743 - acc: 0.9762 - val_loss: 0.5031 - val_acc: 0.8413
# Epoch 25/25
# 16/16 [==============================] - ETA: 0s - loss: 0.0623 - acc: 0.9787
# Epoch 25: val_loss did not improve from 0.31833
# 16/16 [==============================] - 27s 2s/step - loss: 0.0623 - acc: 0.9787 - val_loss: 0.4149 - val_acc: 0.8532

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# # STEP 7. 결과 확인

# %%
# Epoch 별 Loss와 Accuracy를 시각화하세요.
plt.figure(figsize = (16,6))
plt.subplot(1,2,1)





plt.subplot(1,2,2)






plt.show()
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
# 코드를 실행하세요. (label 정보)
indices = training_generator.class_indices
indices = {value : key for key, value in indices.items()}
indices
# Out:
# {0: 'paper', 1: 'rock', 2: 'scissors'}

# %%
# 코드를 실행하세요.
# step1의 subplot에서 title을 예측 결과로 설정하세요.
# 이미지 로드 후 shape를 (-1,150,150,3)으로 변경해야 model.predict 가 가능합니다.
from tensorflow.keras.preprocessing.image import load_img, img_to_array

plt.figure(figsize = (9,9))

for i, c in enumerate(['scissors', 'rock', 'paper']) :
    files = os.listdir(f'data/rps/{c}')[:3]
    for j, file in enumerate(files) :
        plt.subplot(3,3, 3*i + j + 1)

        # 이미지 로드
        image = load_img(f'data/rps/{c}/{file}', target_size=(150, 150))
        image = img_to_array(image) / 255
        
        # plot
        plt.imshow(image)
        plt.axis(False)
        plt.title(f'Predict : {indices[model.predict(image.reshape(-1,150,150,3)).argmax()]}')
plt.show()
